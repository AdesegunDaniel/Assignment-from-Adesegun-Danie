# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # MY JUPYTER NOTEBOOK ON IBM STUDIO

# %% [markdown]
# Bold text:__Adesegun Oluwademilade Daniel__
# I work as a Mechanical Engineer, but I'm highly intrested in becoming a Data scientist

# %% [markdown]
# Italic text:_Data science has very wide range of posibilities, this makes it a point of intrest to me, And also for its remote job offring_

# %% [markdown]
# ### the code below is written to meet and say hi to my peers.(pls note to re-run the code over restart the kernel by cliking the refresh icon third place to run)

# %%
# pls restart kernel to re-run the code or else it won't run again
print("Hello!, My Name is Daniel.")
yourname= str(input("Whats your name?"))
print("It's a plesure to meet you %s, hope you have a nice and happy time learning" %(yourname))
# Out:
# Hello!, My Name is Daniel.

# %% [markdown]
# ***
# * the line above solve for horizontal line evaluation
# * this section solve for buleting list
# * the next section will solve for a table.
# * and the last will be for image making it four thanks
# |NUMBERS|ALPHABET|MATH SIGNS|ROMAN FIG|
# |-------|--------|----------|---------|
# |1|A|+|I|
# |2|B|-|II|
# |3|C|/|III|
# |4|D|x|IV|
# ![images 1.jpg](attachment:25124364-bb80-4924-acac-60efab73d564.jpg)
